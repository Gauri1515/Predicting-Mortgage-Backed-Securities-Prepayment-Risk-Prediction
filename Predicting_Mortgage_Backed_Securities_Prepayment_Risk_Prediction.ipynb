# %% [markdown]
# #**Predicting Mortgage Backed Securities Prepayment Risk Prediction**

# %% [markdown]
# #**Importing Data & Needed Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import statsmodels.api as sm
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
import warnings
warnings.filterwarnings("ignore")
import matplotlib
warnings.filterwarnings("always")

# %matplotlib inline

# %%
data = pd.read_csv('LoanExport.csv')
data.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#     CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0             0            199902                  N        202901  16974
# 1             0            199902                  N        202901  19740
# 2             0            199902                  N        202901  29940
# 3             0            199902                  N        202901  31084
# 4             0            199902                  N        202901  35644
# 5             0            199902                  N        202901  X
# 6             0            199902                  N        202901  X
# 7             0            199902                  X        202901  36740
# 8             0            199902                  Y        202710  25540
# 9             0            199902                  Y        202901  48620
# 10            0            199903                  N        202902  12060
# 11            0            199903                  N        202902  12060
# 12            0            199903                  N        202902  12060
# 13            0            199903                  N        202902  12060
# 14            0            199903                  N        202902  12060
# 15            0            199903                  N        202902  12060
# 16            0            199903                  N        202902  12060
# 17            0            199903                  N        202902  12420
# 18            0            199903                  N        202902  13140
# 19            0            199903                  N        202902  13644
#
#     MIP  Units Occupancy  OCLTV  DTI  ...  PostalCode    LoanSeqNum  \
# 0    25      1         O     89   27  ...       60400  F199Q1268030
# 1     0      1         O     73   17  ...       80200  F199Q1015092
# 2     0      1         O     75   16  ...       66000  F199Q1266886
# 3     0      1         O     76   14  ...       90700  F199Q1178167
# 4     0      1         O     78   18  ...        7600  F199Q1178517
# 5    25      1         O     89   40  ...       80400  F199Q1224802
# 6    25      1         O     90   21  ...       53100  F199Q1291436
# 7     0      1         O     72   20  ...       32800  F199Q1001824
# 8    30      1         O     95   38  ...        6400  F199Q1079744
# 9    30      1         O     95   27  ...       67000  F199Q1196318
# 10    0      1         O     80   19  ...       30100  F199Q1309144
# 11   12      1         O     77   18  ...       30000  F199Q1363208
# 12   12      1         O     85   38  ...       30100  F199Q1388109
# 13   25      1         O     90   19  ...       30600  F199Q1388083
# 14   25      1         O     90   23  ...       30200  F199Q1312860
# 15   25      1         O     90   45  ...       30300  F199Q1271788
# 16   30      1         O     95   28  ...       30000  F199Q1311724
# 17   25      1         O     90   27  ...       78700  F199Q1330011
# 18   25      1         O     90   29  ...       77700  F199Q1321742
# 19   25      1         O     90   15  ...       20800  F199Q1245176
#
#     LoanPurpose OrigLoanTerm NumBorrowers SellerName          ServicerName  \
# 0             P          360            2         FL  WASHINGTONMUTUALBANK
# 1             N          360            1         FT  CHASEHOMEFINANCELLC
# 2             N          360            2         FL  WASHINGTONMUTUALBANK
# 3             N          360            2         GM  GMACMTGECORP
# 4             N          360            2         GM  GMACMTGECORP
# 5             N          360            2         Ot  Other servicers
# 6             P          360            1         RE  Other servicers
# 7             N          360            1         NO   WELLSFARGOBANKNA
# 8             P          345            1         Ot  Other servicers
# 9             P          360            1         Ot   WELLSFARGOBANKNA
# 10            P          360            2         Ot  Other servicers
# 11            C          360            1         ST   ABNAMROMTGEGROUPINC
# 12            P          360            1         Ot   BANKOFAMERICANA
# 13            N          360            2         Ot   BANKOFAMERICANA
# 14            P          360            2         ST  CHASEMANHATTANMTGECO
# 15            N          360            1         Ot   BANKOFAMERICANA
# 16            P          360            1         CR  CHASEMANHATTANMTGECO
# 17            P          360            2         Ot   HOMESIDELENDINGINC
# 18            P          360            2         CH  CHASEMTGECO
# 19            P          360            1         FI  WELLSFARGOHOMEMORTGA
#
#    EverDelinquent  MonthsDelinquent MonthsInRepayment
# 0             0.0               0.0              52.0
# 1             0.0               0.0             144.0
# 2             0.0               0.0              67.0
# 3             0.0               0.0              35.0
# 4             0.0               0.0              54.0
# 5             0.0               0.0              42.0
# 6             0.0               0.0              44.0
# 7             1.0               3.0             145.0
# 8             0.0               0.0              64.0
# 9             1.0             104.0             212.0
# 10            0.0               0.0              37.0
# 11            0.0               0.0              47.0
# 12            0.0               0.0              53.0
# 13            0.0               0.0              55.0
# 14            0.0               0.0              66.0
# 15            1.0               5.0              55.0
# 16            1.0              23.0              55.0
# 17            0.0               0.0              26.0
# 18            0.0               0.0              38.0
# 19            0.0               0.0              36.0
#
# [20 rows x 28 columns]

# %% [markdown]
# **Data Preprocessing & EDA**

# %%
data.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (8288, 28)

# %%
# Checking informations about our features
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8288 entries, 0 to 8287
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CreditScore         8288 non-null   int64
#  1   FirstPaymentDate    8288 non-null   int64
#  2   FirstTimeHomebuyer  8288 non-null   object
#  3   MaturityDate        8288 non-null   int64
#  4   MSA                 8288 non-null   object
#  5   MIP                 8288 non-null   int64
#  6   Units               8288 non-null   int64
#  7   Occupancy           8288 non-null   object
#  8   OCLTV               8288 non-null   int64
#  9   DTI                 8288 non-null   int64
#  10  OrigUPB             8288 non-null   int64
#  11  LTV                 8288 non-null   int64
#  12  OrigInterestRate    8288 non-null   float64
#  13  Channel             8288 non-null   object
#  14  PPM                 8288 non-null   object
#  15  ProductType         8288 non-null   object
#  16  PropertyState       8288 non-null   object
#  17  PropertyType        8288 non-null   object
#  18  PostalCode          8288 non-null   int64
#  19  LoanSeqNum          8288 non-null   object
#  20  LoanPurpose         8288 non-null   object
#  21  OrigLoanTerm        8288 non-null   int64
#  22  NumBorrowers        8288 non-null   object
#  23  SellerName          7506 non-null   object
#  24  ServicerName        8287 non-null   object
#  25  EverDelinquent      8287 non-null   float64
#  26  MonthsDelinquent    8287 non-null   float64
#  27  MonthsInRepayment   8287 non-null   float64
# dtypes: float64(4), int64(11), object(13)
# memory usage: 1.8+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# CreditScore             0
# FirstPaymentDate        0
# FirstTimeHomebuyer      0
# MaturityDate            0
# MSA                     0
# MIP                     0
# Units                   0
# Occupancy               0
# OCLTV                   0
# DTI                     0
# OrigUPB                 0
# LTV                     0
# OrigInterestRate        0
# Channel                 0
# PPM                     0
# ProductType             0
# PropertyState           0
# PropertyType            0
# PostalCode              0
# LoanSeqNum              0
# LoanPurpose             0
# OrigLoanTerm            0
# NumBorrowers            0
# SellerName            782
# ServicerName            1
# EverDelinquent          1
# MonthsDelinquent        1
# MonthsInRepayment       1
# dtype: int64

# %%
#checking for duplicates values to drop them
duplicate=data.duplicated()
print(duplicate.sum())
# Out:
# 0
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Check if there's any categorical features in our data
data.dtypes
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# CreditScore             int64
# FirstPaymentDate        int64
# FirstTimeHomebuyer     object
# MaturityDate            int64
# MSA                    object
# MIP                     int64
# Units                   int64
# Occupancy              object
# OCLTV                   int64
# DTI                     int64
# OrigUPB                 int64
# LTV                     int64
# OrigInterestRate      float64
# Channel                object
# PPM                    object
# ProductType            object
# PropertyState          object
# PropertyType           object
# PostalCode              int64
# LoanSeqNum             object
# LoanPurpose            object
# OrigLoanTerm            int64
# NumBorrowers           object
# SellerName             object
# ServicerName           object
# EverDelinquent        float64
# MonthsDelinquent      float64
# MonthsInRepayment     float64
# dtype: object

# %%
# Convert date feature to datetime format
data['MaturityDate'] = data['MaturityDate'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m'))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data['FirstPaymentDate'] = data['FirstPaymentDate'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m'))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Visualize the change on dtypes of features
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8288 entries, 0 to 8287
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CreditScore         8288 non-null   int64
#  1   FirstPaymentDate    8288 non-null   datetime64[ns]
#  2   FirstTimeHomebuyer  8288 non-null   object
#  3   MaturityDate        8288 non-null   datetime64[ns]
#  4   MSA                 8288 non-null   object
#  5   MIP                 8288 non-null   int64
#  6   Units               8288 non-null   int64
#  7   Occupancy           8288 non-null   object
#  8   OCLTV               8288 non-null   int64
#  9   DTI                 8288 non-null   int64
#  10  OrigUPB             8288 non-null   int64
#  11  LTV                 8288 non-null   int64
#  12  OrigInterestRate    8288 non-null   float64
#  13  Channel             8288 non-null   object
#  14  PPM                 8288 non-null   object
#  15  ProductType         8288 non-null   object
#  16  PropertyState       8288 non-null   object
#  17  PropertyType        8288 non-null   object
#  18  PostalCode          8288 non-null   int64
#  19  LoanSeqNum          8288 non-null   object
#  20  LoanPurpose         8288 non-null   object
#  21  OrigLoanTerm        8288 non-null   int64
#  22  NumBorrowers        8288 non-null   object
#  23  SellerName          7506 non-null   object
#  24  ServicerName        8287 non-null   object
#  25  EverDelinquent      8287 non-null   float64
#  26  MonthsDelinquent    8287 non-null   float64
#  27  MonthsInRepayment   8287 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(9), object(13)
# memory usage: 1.8+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#View description of all of our features
num1_cols = data.describe(include='all')
num1_cols
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-10-73e8b8f9509f>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   num1_cols = data.describe(include='all')
# <ipython-input-10-73e8b8f9509f>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   num1_cols = data.describe(include='all')
#         CreditScore     FirstPaymentDate FirstTimeHomebuyer  \
# count   8288.000000                 8288               8288
# unique          NaN                   31                  3
# top             NaN  1999-05-01 00:00:00                  N
# freq            NaN                 3108               4722
# first           NaN  1999-02-01 00:00:00                NaN
# last            NaN  2003-04-01 00:00:00                NaN
# mean     497.931226                  NaN                NaN
# std      205.132493                  NaN                NaN
# min        0.000000                  NaN                NaN
# 25%      552.000000                  NaN                NaN
# 50%      584.000000                  NaN                NaN
# 75%      599.000000                  NaN                NaN
# max      607.000000                  NaN                NaN
#
#                MaturityDate    MSA          MIP        Units Occupancy  \
# count                  8288   8288  8288.000000  8288.000000      8288
# unique                   56    354          NaN          NaN         3
# top     2029-04-01 00:00:00  X              NaN          NaN         O
# freq                   3103   1194          NaN          NaN      7982
# first   2024-09-01 00:00:00    NaN          NaN          NaN       NaN
# last    2030-10-01 00:00:00    NaN          NaN          NaN       NaN
# mean                    NaN    NaN    12.749035     1.029199       NaN
# std                     NaN    NaN    13.259903     0.208117       NaN
# min                     NaN    NaN     0.000000     1.000000       NaN
# 25%                     NaN    NaN     0.000000     1.000000       NaN
# 50%                     NaN    NaN    12.000000     1.000000       NaN
# 75%                     NaN    NaN    25.000000     1.000000       NaN
# max                     NaN    NaN    52.000000     4.000000       NaN
#
#               OCLTV          DTI  ...    PostalCode    LoanSeqNum  \
# count   8288.000000  8288.000000  ...   8288.000000          8288
# unique          NaN          NaN  ...           NaN          8288
# top             NaN          NaN  ...           NaN  F199Q1268030
# freq            NaN          NaN  ...           NaN             1
# first           NaN          NaN  ...           NaN           NaN
# last            NaN          NaN  ...           NaN           NaN
# mean      80.860763    29.553571  ...  53255.091699           NaN
# std       13.005811    13.156933  ...  30311.163141           NaN
# min        7.000000     0.000000  ...    600.000000           NaN
# 25%       75.000000    22.000000  ...  29500.000000           NaN
# 50%       80.000000    31.000000  ...  48300.000000           NaN
# 75%       90.000000    39.000000  ...  84100.000000           NaN
# max      103.000000    65.000000  ...  99700.000000           NaN
#
#         LoanPurpose OrigLoanTerm NumBorrowers SellerName  \
# count          8288  8288.000000         8288       7506
# unique            3          NaN            3         20
# top               P          NaN            2         Ot
# freq           3578          NaN         5219       2170
# first           NaN          NaN          NaN        NaN
# last            NaN          NaN          NaN        NaN
# mean            NaN   359.702461          NaN        NaN
# std             NaN     3.006374          NaN        NaN
# min             NaN   306.000000          NaN        NaN
# 25%             NaN   360.000000          NaN        NaN
# 50%             NaN   360.000000          NaN        NaN
# 75%             NaN   360.000000          NaN        NaN
# max             NaN   360.000000          NaN        NaN
#
#                 ServicerName EverDelinquent  MonthsDelinquent  \
# count                   8287    8287.000000       8287.000000
# unique                    20            NaN               NaN
# top     Other servicers                 NaN               NaN
# freq                    2187            NaN               NaN
# first                    NaN            NaN               NaN
# last                     NaN            NaN               NaN
# mean                     NaN       0.440087          6.433088
# std                      NaN       0.496427         16.473469
# min                      NaN       0.000000          0.000000
# 25%                      NaN       0.000000          0.000000
# 50%                      NaN       0.000000          0.000000
# 75%                      NaN       1.000000          4.000000
# max                      NaN       1.000000        180.000000
#
#        MonthsInRepayment
# count        8287.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# first                NaN
# last                 NaN
# mean           63.205623
# std            50.595431
# min             1.000000
# 25%            33.000000
# 50%            49.000000
# 75%            69.000000
# max           212.000000
#
# [13 rows x 28 columns]

# %%
#Count number of distinct elements in axis 0.
data.nunique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# CreditScore            142
# FirstPaymentDate        31
# FirstTimeHomebuyer       3
# MaturityDate            56
# MSA                    354
# MIP                     18
# Units                    4
# Occupancy                3
# OCLTV                   83
# DTI                     66
# OrigUPB                270
# LTV                     82
# OrigInterestRate        66
# Channel                  4
# PPM                      3
# ProductType              1
# PropertyState           53
# PropertyType             6
# PostalCode             743
# LoanSeqNum            8288
# LoanPurpose              3
# OrigLoanTerm            44
# NumBorrowers             3
# SellerName              20
# ServicerName            20
# EverDelinquent           2
# MonthsDelinquent       134
# MonthsInRepayment      212
# dtype: int64

# %%
data["EverDelinquent"].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.0    4640
# 1.0    3647
# Name: EverDelinquent, dtype: int64

# %%
print("Seller Name size: \n",data.SellerName.value_counts(),"\n\n")
# Out:
# Seller Name size:
#  Ot    2170
# NO     866
# ST     633
# FI     627
# FL     474
# GM     346
# CO     327
# BA     294
# WA     292
# FT     249
# BI     202
# PR     170
# OL     167
# CH     165
# PN     141
# AC     120
# HO     110
# CR      78
# G       42
# RE      33
# Name: SellerName, dtype: int64
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Return unique values based on a hash table.
data['FirstTimeHomebuyer'].unique()
# X means No
# Y means Yes
# N means Unknown value
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['N', 'X', 'Y'], dtype=object)

# %%
data['PPM'].unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['N', 'X', 'Y'], dtype=object)

# %%
data['NumBorrowers'].unique()
# X  means unknown value
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['2', '1', 'X '], dtype=object)

# %% [markdown]
# #**DATA ENCODING**
#
# Encoding the categorical columns
#
# 1 - Label Encoder - If you have 2 categories which may or may not be not in order then you use label encoder
#
# 2 - one hot Encoder - more then number of categories you use one hot encoding which means that you are converting a value in the row into a column

# %%
# Define the columns to be label encoded and one-hot encoded
label_encode_columns = ['CreditScore', 'LoanPurpose']  # Replace with your column names
one_hot_encode_columns = ['Occupancy', 'SellerName']  # Replace with your column names
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in label_encode_columns:
    data[column] = label_encoder.fit_transform(data[column])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Apply One-Hot Encoding to selected columns
one_hot_encoder = OneHotEncoder(drop='first', sparse=False)
encoded_data = one_hot_encoder.fit_transform(data[one_hot_encode_columns])

# Get the column names for the one-hot encoded columns
encoded_column_names = one_hot_encoder.get_feature_names_out(input_features=one_hot_encode_columns)

# Create a DataFrame with the encoded data and column names
encoded_data = pd.DataFrame(encoded_data, columns=encoded_column_names)

# Combine the encoded data with the original DataFrame
data = pd.concat([data, encoded_data], axis=1)

# Drop the original columns that were one-hot encoded
data.drop(one_hot_encode_columns, axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# #**DATA LABELLING**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Assuming you have a column named 'CreditScore' containing non-numeric labels
# You can use LabelEncoder to encode it
label_encoder = LabelEncoder()
data['CreditScore'] = label_encoder.fit_transform(data['CreditScore'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
